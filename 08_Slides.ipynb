# %% [markdown]
# - Success rate per variable (country, category, subcatogery duration, goal)
# - mean goal, pledged per variable
# -

# %%
#import
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

df = pd.read_csv("data/binary_state_kickstarter_projects.csv") 
df.head()
# Out:
#        category   subcategory        country             launched    deadline
# 0       Fashion       Fashion  United States  2009-04-21 21:02:48  2009-05-31  \
# 1  Film & Video        Shorts  United States  2009-04-23 00:07:53  2009-07-20
# 2           Art  Illustration  United States  2009-04-24 21:52:03  2009-05-03
# 3    Technology      Software  United States  2009-04-25 17:36:21  2009-07-14
# 4       Fashion       Fashion  United States  2009-04-27 14:10:39  2009-05-26
#
#     goal  pledged  backers  state  duration  launch_month   org_state
# 0   1000      625       30      0        39             4      Failed  \
# 1  80000       22        3      0        87             4      Failed
# 2     20       35        3      1         8             4  Successful
# 3     99      145       25      1        79             4  Successful
# 4   1900      387       10      0        28             4      Failed
#
#    country_encoded  category_encoded  subcategory_encoded   goal_log
# 0               21                 5                   52   6.908755  \
# 1               21                 6                  129  11.289794
# 2               21                 0                   70   3.044522
# 3               21                13                  131   4.605170
# 4               21                 5                   52   7.550135
#
#    pledged_log
# 0     6.439350
# 1     3.135494
# 2     3.583519
# 3     4.983607
# 4     5.961005

# %%
# Function to set the plot style
def set_plot_style():
    # Set the background color of the plot
    plt.gca().set_facecolor('#002845')
    plt.gcf().set_facecolor('#002845')
    # Set the title and axis labels with white color
    plt.title('Title', color='white')
    plt.xlabel('X Label', color='white')
    plt.ylabel('Y Label', color='white')
    # Set the color of tick labels
    plt.xticks(color='white')
    plt.yticks(color='white')

# %% [markdown]
# # Category

# %%
# Group by 'category' and calculate the mean of 'state'
success_rate = df.groupby('category', sort=True)['state'].count().sort_values(ascending=False).reset_index()
success_rate.columns = ['category', 'success_rate']

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(y='category', x='success_rate', data=success_rate)
plt.title('Count per Category')
plt.ylabel('Count')
plt.xlabel('Category')
plt.show()

# %%
# Group by 'category' and calculate the mean of 'state'
success_rate = df.groupby('category')['state'].mean().sort_values(ascending=False).reset_index()
success_rate.columns = ['category', 'success_rate']

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(y='category', x='success_rate', data=success_rate)
plt.title('Avg. Success Rate per Category')
plt.ylabel('Avg. Success Rate')
plt.xlabel('Category')
plt.show()

# %%
# Group by 'category' and calculate the mean of 'state'
success_rate = df.groupby('category')['goal'].median().sort_values(ascending=False).reset_index()
success_rate.columns = ['category', 'success_rate']

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(y='category', x='success_rate', data=success_rate)
plt.title('Median Goal per Category')
plt.ylabel('Median Goal')
plt.xlabel('Category')
plt.show()

# %%
# Group by 'category' and calculate the mean of 'state'
success_rate = df.groupby('category')['pledged'].median().sort_values(ascending=False).reset_index()
success_rate.columns = ['category', 'success_rate']

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(y='category', x='success_rate', data=success_rate)
plt.title('Median Pledged per Category')
plt.ylabel('Median Pledged')
plt.xlabel('Category')
plt.show()

# %% [markdown]
# # Country

# %%
# Group by 'category' and calculate the mean of 'state'
success_rate = df.groupby('country')['state'].mean().sort_values(ascending=False).reset_index()
success_rate.columns = ['country', 'success_rate']

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(y='country', x='success_rate', data=success_rate)
plt.title('Avg. Success Rate per Country')
plt.ylabel('Avg. Success Rate')
plt.xlabel('Country')
plt.show()

# %%
# Group by 'category' and calculate the mean of 'state'
success_rate = df.groupby('country')['goal'].median().sort_values(ascending=False).reset_index()
success_rate.columns = ['country', 'success_rate']

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(y='country', x='success_rate', data=success_rate)
plt.title('Median Goal per Country')
plt.ylabel('Median Goal')
plt.xlabel('Country')
plt.show()

# %%
# Group by 'category' and calculate the mean of 'state'
success_rate = df.groupby('country')['pledged'].median().sort_values(ascending=False).reset_index()
success_rate.columns = ['country', 'success_rate']

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(y='country', x='success_rate', data=success_rate)
plt.title('Median Pledged per Country')
plt.ylabel('Median Pledged')
plt.xlabel('Country')
plt.show()

# %% [markdown]
# # Duration

# %%
# Group by 'category' and calculate the mean of 'state'
success_rate = df.groupby('duration')['state'].median().sort_values(ascending=False).reset_index()
success_rate.columns = ['duration', 'success_rate']

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='duration', y='success_rate', data=success_rate)
plt.title('Median Pledged per Country')
plt.ylabel('Median Pledged')
plt.xlabel('Duration')
plt.show()
