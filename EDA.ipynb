# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data/kickstarter_projects.csv')
df.head()
# Out:
#            ID                                               Name
# 0  1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...  \
# 1   709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# 2  1703704063                                drawing for dollars
# 3      727286                       Offline Wikipedia iPhone app
# 4  1622952265                                         Pantshirts
#
#        Category   Subcategory        Country             Launched    Deadline
# 0       Fashion       Fashion  United States  2009-04-21 21:02:48  2009-05-31  \
# 1  Film & Video        Shorts  United States  2009-04-23 00:07:53  2009-07-20
# 2           Art  Illustration  United States  2009-04-24 21:52:03  2009-05-03
# 3    Technology      Software  United States  2009-04-25 17:36:21  2009-07-14
# 4       Fashion       Fashion  United States  2009-04-27 14:10:39  2009-05-26
#
#     Goal  Pledged  Backers       State
# 0   1000      625       30      Failed
# ...

# %%
df.shape
# Out:
# (374853, 11)

# %%
df.isna().sum()
# Out:
# ID             0
# Name           0
# Category       0
# Subcategory    0
# Country        0
# Launched       0
# Deadline       0
# Goal           0
# Pledged        0
# Backers        0
# State          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374853 entries, 0 to 374852
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ID           374853 non-null  int64
#  1   Name         374853 non-null  object
#  2   Category     374853 non-null  object
#  3   Subcategory  374853 non-null  object
#  4   Country      374853 non-null  object
#  5   Launched     374853 non-null  object
#  6   Deadline     374853 non-null  object
#  7   Goal         374853 non-null  int64
#  8   Pledged      374853 non-null  int64
#  9   Backers      374853 non-null  int64
#  10  State        374853 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 31.5+ MB

# %%
df_can = df[df['State'].isin(['Canceled'])]
print(df_can.shape)
percentage_lost = (df_can.shape[0] / df.shape[0]) * 100
print(str(round(percentage_lost,2)) + '%')
# Out:
# (38751, 11)
# 10.34%

# %%
df_sus = df[df['State'].isin(['Suspended'])]
print(df_sus.shape)
percentage_lost = (df_sus.shape[0] / df.shape[0]) * 100
print(str(round(percentage_lost,2)) + '%')
# Out:
# (1842, 11)
# 0.49%

# %%
df_sus.head(100)
# Out:
#                ID                                               Name
# 4758    323824315  Boobs, Breasts, and Sex Appeal : : An artistic...  \
# 6399    546540380  http://boo.bs - fighting breast cancer with so...
# 6468    605472774  The Right to Climb: Revolutionizing Support fo...
# 6741   2127489984  Let's get Kill Kill Kill to Japan with a 7" re...
# 6757    313825513  SwipeGood - Swipe your card. Change the world....
# ...           ...                                                ...
# 63677   294829916  Freedom Sleeve: Turn your iPod into an iPhone ...
# 63857  1538611763   Brittle Mama - Best Bite You'll Take (Suspended)
# 64377  2075318164  AmbioLight: Atmosphere changing LED lighting (...
# 64579  1131629221                                MY CITY (Suspended)
# 64656  2033339396                        I am MONKEY !!! (Suspended)
#
#            Category     Subcategory        Country             Launched
# ...

# %%
goal_zero = df[df['Goal'] == 0]

# %%
goal_zero
# Out:
#                 ID                                               Name
# 1085     620302213            LOVELAND Round 6: A Force More Powerful  \
# 33831    688564643  Word-of-mouth publishing: get "Corruptions" ou...
# 40294      9572984                                               Nana
# 316197  1379346088                Bug's Big Adventure: Mexico Edition
#
#             Category     Subcategory        Country             Launched
# 1085             Art  Conceptual Art  United States  2009-11-25 07:54:49  \
# 33831     Publishing         Fiction  United States  2011-11-07 16:46:52
# 40294   Film & Video          Shorts  United States  2012-01-25 07:23:19
# 316197           Art             Art         Mexico  2016-11-11 16:30:00
#
#           Deadline  Goal  Pledged  Backers       State
# 1085    2009-12-04     0      100        6  Successful
# 33831   2011-12-13     0        0        0    Canceled
# 40294   2012-03-16     0        0        0      Failed
# ...
